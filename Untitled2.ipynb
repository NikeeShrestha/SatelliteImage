# %%
import torchvision
import torch
import torchvision.transforms as transforms
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import glob
import PIL
import rasterio

class satelliteimage_dataset(torch.utils.data.Dataset):
    def __init__(self,image_path, label_path):
       self.imagepath=image_path
       assert os.path.exists(self.imagepath) ##if its true nothing happens
       assert os.path.exists(label_path) ##same

       self.all_label= pd.read_csv(label_path,index_col=0)
       self.all_filenames= glob.glob(os.path.join(image_path, '*.TIF'))
    #    print(self.all_filenames)
    #    self.all_filenames=np.array(self.all_filenames)
    
    def __len__(self):
        return len(self.all_filenames)
        return len(self.all_label)
    
    def __getitem__(self, idx):
        selected_filename= self.all_filenames[idx].split("/")[-1]
        # print(selected_filename)
        # imagepil= PIL.Image.open(os.path.join(self.imagepath, selected_filename))

        if selected_filename not in self.all_label.index:
            print(selected_filename, "no data for this file")
            return self.__getitem__((idx + 1) % len(self))
        
        with rasterio.open(os.path.join(self.imagepath, selected_filename), 'r') as src:
            image=src.read()
            # print(image.shape)
            image = image.astype(np.float32)
            # print(image.shape)
            image = image.transpose((1,2,0))
            # image = (image - image.min()) / (image.max() - image.min())

        # transform = transforms.Compose([
        #     # transforms.Resize((27, 12)),
        #     transforms.ToTensor(),
        #     #transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])  # Adjust mean and std as needed
        # ])
        # image=transform(image) ## model learns better ## we want all the data to be on same scale
        # print(image.shape)
        label =torch.Tensor(self.all_label.loc[selected_filename,:].values)
        filename=selected_filename
        # print(label.shape)

        return image, label, filename

# %%
dataset = satelliteimage_dataset(image_path='../ImageDataset/SixBndImages/Crawfordsville/Hybrids/CroppedTP2/', label_path='Data/HipsData_TP2_CrawFordsville_yield.csv')

# %%
dataset[5]
# Out:
# (array([[[ 779.,  893.,  662., 5781., 2527.,  567.],
#          [ 419.,  607.,  420., 4790., 2104.,  388.],
#          [ 471.,  651.,  457., 4953., 2179.,  418.],
#          ...,
#          [ 480.,  641.,  483., 4957., 2184.,  441.],
#          [ 783.,  881.,  687., 5788., 2540.,  600.],
#          [   0.,    0.,    0.,    0.,    0.,    0.]],
#
#         [[ 779.,  893.,  662., 5781., 2527.,  567.],
#          [ 419.,  607.,  420., 4790., 2104.,  388.],
#          [ 471.,  651.,  457., 4953., 2179.,  418.],
#          ...,
#          [ 480.,  641.,  483., 4957., 2184.,  441.],
#          [ 783.,  881.,  687., 5788., 2540.,  600.],
#          [   0.,    0.,    0.,    0.,    0.,    0.]],
#
#         [[ 703.,  838.,  610., 5706., 2503.,  527.],
#          [ 402.,  599.,  407., 4863., 2140.,  380.],
#          [ 380.,  586.,  395., 4815., 2121.,  376.],
#          ...,
#          [ 318.,  519.,  370., 4604., 2030.,  367.],
#          [ 660.,  789.,  600., 5550., 2437.,  544.],
# ...

# %%
dataset.transform=trainTransforms

# %%
dataset[5]
# Out:
# (array([[[ 779.,  893.,  662., 5781., 2527.,  567.],
#          [ 419.,  607.,  420., 4790., 2104.,  388.],
#          [ 471.,  651.,  457., 4953., 2179.,  418.],
#          ...,
#          [ 480.,  641.,  483., 4957., 2184.,  441.],
#          [ 783.,  881.,  687., 5788., 2540.,  600.],
#          [   0.,    0.,    0.,    0.,    0.,    0.]],
#
#         [[ 779.,  893.,  662., 5781., 2527.,  567.],
#          [ 419.,  607.,  420., 4790., 2104.,  388.],
#          [ 471.,  651.,  457., 4953., 2179.,  418.],
#          ...,
#          [ 480.,  641.,  483., 4957., 2184.,  441.],
#          [ 783.,  881.,  687., 5788., 2540.,  600.],
#          [   0.,    0.,    0.,    0.,    0.,    0.]],
#
#         [[ 703.,  838.,  610., 5706., 2503.,  527.],
#          [ 402.,  599.,  407., 4863., 2140.,  380.],
#          [ 380.,  586.,  395., 4815., 2121.,  376.],
#          ...,
#          [ 318.,  519.,  370., 4604., 2030.,  367.],
#          [ 660.,  789.,  600., 5550., 2437.,  544.],
# ...

# %%
band_values = [[] for _ in range(6)]  # Assuming 6 bands

# Iterate through the dataset to collect pixel values
for idx in range(len(dataset)):
    image, _, _ = dataset[idx]
    for band in range(6):  # Assuming 6 bands
        band_values[band].extend(image[band].flatten())
# Out:
# Crawfordsville-TP2-4352_6_7_cropped.TIF no data for this file
# Crawfordsville-TP2-4351_10_19_cropped.TIF no data for this file
# Crawfordsville-TP2-4352_10_9_cropped.TIF no data for this file
# Crawfordsville-TP2-4352_2_3_cropped.TIF no data for this file
# Crawfordsville-TP2-4351_17_14_cropped.TIF no data for this file
# Crawfordsville-TP2-4352_20_3_cropped.TIF no data for this file
# Crawfordsville-TP2-4353_3_45_cropped.TIF no data for this file
# Crawfordsville-TP2-4351_4_19_cropped.TIF no data for this file
# Crawfordsville-TP2-4351_6_15_cropped.TIF no data for this file
# Crawfordsville-TP2-4353_32_43_cropped.TIF no data for this file
# Crawfordsville-TP2-4352_10_4_cropped.TIF no data for this file
# Crawfordsville-TP2-4351_4_18_cropped.TIF no data for this file
# Crawfordsville-TP2-4351_4_18_cropped.TIF no data for this file
# Crawfordsville-TP2-4353_5_42_cropped.TIF no data for this file
# Crawfordsville-TP2-4352_11_2_cropped.TIF no data for this file
# ...

# %%
mean_per_band = [np.mean(band) for band in band_values]
std_per_band = [np.std(band) for band in band_values]

print("Mean per band:", mean_per_band)
print("Std per band:", std_per_band)
# Out:
# Mean per band: [1034.5037, 1034.5037, 1329.6132, 1329.6132, 1354.5366, 1354.5366]
# Std per band: [1430.3986, 1430.3986, 1530.8733, 1530.8733, 1563.9932, 1563.9932]

# %%
hFlip = transforms.RandomHorizontalFlip(p=0.25)
vFlip = transforms.RandomVerticalFlip(p=0.25)
rotate = transforms.RandomRotation(degrees=15)
normalize=transforms.Normalize(mean=mean_per_band, std=std_per_band)

# %%
print(normalize)
# Out:
# Normalize(mean=[1034.5037, 1034.5037, 1329.6132, 1329.6132, 1354.5366, 1354.5366], std=[1430.3986, 1430.3986, 1530.8733, 1530.8733, 1563.9932, 1563.9932])

# %%
trainTransforms = transforms.Compose([hFlip, vFlip, rotate,normalize,
        transforms.ToTensor()])
valTransforms = transforms.Compose([normalize,transforms.ToTensor()])

# %%
dataset.transfrom=trainTransforms

# %%
# for i in range(len(trainData)):
#     sample, _, _ = trainData[i]
#     print(sample.min(), sample.max())

# %%
trainSize = int(dataset.__len__() * 0.8)
testSize = dataset.__len__() - trainSize
trainData, testData = torch.utils.data.random_split(dataset, [trainSize, testSize])
trainData.dataset.transform=trainTransforms
trainLoader=torch.utils.data.DataLoader(dataset=trainData, batch_size=1, shuffle=True)
testLoader=torch.utils.data.DataLoader(dataset=testData, batch_size=1, shuffle=True)

# %%
trainLoader

# %%
for batchindex, (image, label, _) in enumerate(trainLoader):
    img=(np.transpose(image[0].numpy(), (1, 2, 0)))
    plt.imshow(img[:,:,[0,1,2]])  # Assuming you want to display the first channel
    plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...
